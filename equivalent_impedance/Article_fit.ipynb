# %%
import quick_eq_imp
import analysis

import matplotlib.pyplot as plt
import numpy as np

# %%
article_theoretical_data = [4.38820638820639,11.795249795249795,15.031941031941033,16.33906633906634,16.992628992628994,17.45945945945946,17.615069615069615,17.77067977067977,17.895167895167894]

# %% [markdown]
# ## Circuit with capacity to ground

# %%
quick_eq_imp.initialize_file_mass_capa_z_eq()

# %%
n_jct = 20
y_eqs = quick_eq_imp.equivalent_impedance(n_jct=n_jct,
                                          mass_capa=True,
                                          all_eqs=False,
                                          fourier=True,
                                          loss=False,
                                          impedance=False,
                                          messages=True)
# Out:
# Computing additional denominators...
# 100%|██████████| 8/8 [00:00<00:00, 21.72it/s]
# Computing additional equivalent elements..
# 100%|██████████| 8/8 [00:00<00:00, 25.27it/s]
# Computing additional equivalent impedance..
# 100%|██████████| 8/8 [00:00<00:00, 20.76it/s]
# Replacing with element's values..
# 100%|██████████| 1/1 [21:53<00:00, 1313.60s/it]

# %%
L_j0_val = 1.9*80
C_j0_val = 40e-6/80
C_g_val = 1e-7*80/n_jct

C_0_val = 2e-6
fig,ax = plt.subplots(figsize=(12,8))
params = analysis.create_param([L_j0_val,C_j0_val,C_g_val,C_0_val])
f_s = analysis.circuit_resonances(y_eqs[0],params = params,full = False)
modes = [el[0] for el in f_s][:10]
modes[1] = 12
ax.plot(modes,"o-",label=f"Computed")
ax.plot(article_theoretical_data[:-1],"+-",label ="Article")
ax.set_xlabel("Mode index")
ax.set_ylabel("Mode frequency (GHz)")
ax.grid()
ax.legend()
#plt.show()
fig.savefig("article_fit_rep_ground_V2.png")

# %%
fitted_params, fitted_f_s = analysis.eigenmode_fit(article_theoretical_data, y_eqs[0],[L_j0_val,C_j0_val,C_g_val,C_0_val],norm=False)
[L_j0_fit,C_j0_fit,C_g_fit,C_0_fit] = fitted_params
print(f"L_j0_fit : {L_j0_fit} || L_j0_val : {L_j0_val}")
print(f"C_j0_fit : {C_j0_fit} || C_j0_val : {C_j0_val}")
print(f"C_g_fit : {C_g_fit} || C_g_val : {C_g_val}")
print(f"C_0_fit : {C_0_fit} || C_0_val : {C_0_val}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 fitted_params, fitted_f_s = analysis.eigenmode_fit(article_theoretical_data, y_eqs[0],[L_j0_val,C_j0_val,C_g_val,C_0_val],norm=False)
#       2 [L_j0_fit,C_j0_fit,C_g_fit,C_0_fit] = fitted_params
#       3 print(f"L_j0_fit : {L_j0_fit} || L_j0_val : {L_j0_val}")
#
# File ~\Desktop\Work\JJarray_formal\equivalent_impedance\analysis.py:164, in eigenmode_fit(to_fit, y_eq, x0, norm)
#     162         f_s = circuit_resonances(y_eq, params=param, full=False, frequency=True)
#     163         return sum([(f_s[i][0] - to_fit[i])**2 for i in range(min(len(f_s), n_fit))])
# --> 164 res = minimize(cost, x0)
#     165 if not res.success:
#     166     print("Fit failed")
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\_minimize.py:618, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     return _minimize_cg(fun, x0, args, jac, callback, **options)
#     617 elif meth == 'bfgs':
# --> 618     return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     619 elif meth == 'newton-cg':
#     620     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     621                               **options)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\optimize.py:1235, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1232 pk = -np.dot(Hk, gfk)
#    1233 try:
#    1234     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1235              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1236                                   old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1237 except _LineSearchError:
#    1238     # Line search failed to find a better solution.
#    1239     warnflag = 2
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\optimize.py:1005, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     991 """
#     992 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#     993 suitable step length is not found, and raise an exception if a
#    (...)
#    1000
#    1001 """
#    1003 extra_condition = kwargs.pop('extra_condition', None)
# -> 1005 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1006                          old_fval, old_old_fval,
#    1007                          **kwargs)
#    1009 if ret[0] is not None and extra_condition is not None:
#    1010     xp1 = xk + ret[0] * pk
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\linesearch.py:96, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      92     return np.dot(gval[0], pk)
#      94 derphi0 = np.dot(gfk, pk)
# ---> 96 stp, fval, old_fval = scalar_search_wolfe1(
#      97         phi, derphi, old_fval, old_old_fval, derphi0,
#      98         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     100 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\linesearch.py:172, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     170 if task[:2] == b'FG':
#     171     alpha1 = stp
# --> 172     phi1 = phi(stp)
#     173     derphi1 = derphi(stp)
#     174 else:
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\linesearch.py:84, in line_search_wolfe1.<locals>.phi(s)
#      82 def phi(s):
#      83     fc[0] += 1
# ---> 84     return f(xk + s*pk, *args)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\_differentiable_functions.py:249, in ScalarFunction.fun(self, x)
#     247 if not np.array_equal(x, self.x):
#     248     self._update_x_impl(x)
# --> 249 self._update_fun()
#     250 return self.f
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     231 def _update_fun(self):
#     232     if not self.f_updated:
# --> 233         self._update_fun_impl()
#     234         self.f_updated = True
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\scipy\optimize\_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~\Desktop\Work\JJarray_formal\equivalent_impedance\analysis.py:162, in eigenmode_fit.<locals>.cost(x)
#     160 def cost(x):
#     161     param = create_param(x)
# --> 162     f_s = circuit_resonances(y_eq, params=param, full=False, frequency=True)
#     163     return sum([(f_s[i][0] - to_fit[i])**2 for i in range(min(len(f_s), n_fit))])
#
# File ~\Desktop\Work\JJarray_formal\equivalent_impedance\analysis.py:112, in circuit_resonances(Y_eq, var, params, full, frequency, loss)
#     110     coefs_num = [complex(el) for el in sp.poly(num_tot).all_coeffs()[::-1]]
#     111 else:
# --> 112     num_tot = sp.expand((num+sp.I*C_0*var*deno).subs(params)/sp.I)
#     113     coefs_num = [float(el) for el in sp.poly(num_tot).all_coeffs()[::-1]]
#     115 roots_num = np.polynomial.polynomial.polyroots(np.array(coefs_num))
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\function.py:2833, in expand(e, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2831 hints['multinomial'] = multinomial
#    2832 hints['basic'] = basic
# -> 2833 return sympify(e).expand(deep=deep, modulus=modulus, **hints)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\expr.py:3624, in Expr.expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3622     if use_hint:
#    3623         hint = '_eval_expand_' + hint
# -> 3624         expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3626 while True:
#    3627     was = expr
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\expr.py:3557, in Expr._expand_hint(expr, hint, deep, **hints)
#    3555 sargs = []
#    3556 for arg in expr.args:
# -> 3557     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3558     hit |= arghit
#    3559     sargs.append(arg)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\expr.py:3557, in Expr._expand_hint(expr, hint, deep, **hints)
#    3555 sargs = []
#    3556 for arg in expr.args:
# -> 3557     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3558     hit |= arghit
#    3559     sargs.append(arg)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\expr.py:3565, in Expr._expand_hint(expr, hint, deep, **hints)
#    3562         expr = expr.func(*sargs)
#    3564 if hasattr(expr, hint):
# -> 3565     newexpr = getattr(expr, hint)(**hints)
#    3566     if newexpr != expr:
#    3567         return (newexpr, True)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\mul.py:974, in Mul._eval_expand_mul(self, **hints)
#     972 if sums:
#     973     deep = hints.get("deep", False)
# --> 974     terms = self.func._expandsums(sums)
#     975     args = []
#     976     for term in terms:
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\mul.py:937, in Mul._expandsums(sums)
#     935 terms = []
#     936 left = Mul._expandsums(sums[:L//2])
# --> 937 right = Mul._expandsums(sums[L//2:])
#     939 terms = [Mul(a, b) for a in left for b in right]
#     940 added = Add(*terms)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\mul.py:940, in Mul._expandsums(sums)
#     937 right = Mul._expandsums(sums[L//2:])
#     939 terms = [Mul(a, b) for a in left for b in right]
# --> 940 added = Add(*terms)
#     941 return Add.make_args(added)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\add.py:338, in Add.flatten(cls, seq)
#     335             newseq.append(Mul(c, s, evaluate=False))
#     336         else:
#     337             # alternatively we have to call all Mul's machinery (slow)
# --> 338             newseq.append(Mul(c, s))
#     340     noncommutative = noncommutative or not s.is_commutative
#     342 # oo, -oo
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\mul.py:365, in Mul.flatten(cls, seq)
#     363     return [S.NaN], [], None
#     364 elif coeff.is_Number or isinstance(coeff, AccumBounds):  # it could be zoo
# --> 365     coeff *= o
#     366     if coeff is S.NaN:
#     367         # we know for sure the result will be nan
#     368         return [S.NaN], [], None
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\numbers.py:2210, in Integer.__mul__(self, other)
#    2208     elif isinstance(other, Rational):
#    2209         return Rational(self.p*other.p, other.q, igcd(self.p, other.q))
# -> 2210     return Rational.__mul__(self, other)
#    2211 return Rational.__mul__(self, other)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\numbers.py:1744, in Rational.__mul__(self, other)
#    1742     return Rational(self.p*other.p, self.q*other.q, igcd(self.p, other.q)*igcd(self.q, other.p))
#    1743 elif isinstance(other, Float):
# -> 1744     return other*self
#    1745 else:
#    1746     return Number.__mul__(self, other)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\numbers.py:1297, in Float.__mul__(self, other)
#    1295 if isinstance(other, Number) and global_parameters.evaluate:
#    1296     rhs, prec = other._as_mpf_op(self._prec)
# -> 1297     return Float._new(mlib.mpf_mul(self._mpf_, rhs, prec, rnd), prec)
#    1298 return Number.__mul__(self, other)
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\numbers.py:1193, in Float._new(cls, _mpf_, _prec, zero)
#    1190     return S.NegativeInfinity
#    1192 obj = Expr.__new__(cls)
# -> 1193 obj._mpf_ = mpf_norm(_mpf_, _prec)
#    1194 obj._prec = _prec
#    1195 return obj
#
# File ~\anaconda3\envs\drawpy\lib\site-packages\sympy\core\numbers.py:173, in mpf_norm(mpf, prec)
#     170         return mpf
#     172 # Necessary if mpmath is using the gmpy backend
# --> 173 from mpmath.libmp.backend import MPZ
#     174 rv = mpf_normalize(sign, MPZ(man), expt, bc, prec, rnd)
#     175 return rv
#
# KeyboardInterrupt:

# %%
plt.plot([np.sqrt(el[0]**2+el[1]**2) for el in fitted_f_s][:9],"o-",label=f"Zeros of Y_eq (C_0 = {round(C_0_fit*1e6,2)} fF)")
plt.plot(article_theoretical_data,"+-",label ="Article_data")
plt.xlabel("Mode index")
plt.ylabel("Mode frequency (GHz)")
plt.legend()
plt.show()

# %% [markdown]
# ## Circuit with capacity to pads

# %%
n_jct = 20
y_eqs = quick_eq_imp.equivalent_impedance(n_jct = n_jct,
                                          mass_capa = False,
                                          all_eqs = False,
                                          fourier = True,
                                          loss = False,
                                          impedance = False,
                                          messages = True)
# Out:
# Replacing with element's values..
# 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]

# %%
L_j0_val = 1.9*80
C_j0_val = 40e-6/80
C_g_val = 4e-8*80/n_jct/2

C_0_val = 2e-6
fig,ax = plt.subplots(figsize=(12,8))
params = analysis.create_param([L_j0_val,C_j0_val,C_g_val,C_0_val])
f_s = analysis.circuit_resonances(y_eqs[0],params = params,full = False)
ax.plot([el[0] for el in f_s[:9]],"o-",label=f"Computed")
ax.plot(article_theoretical_data[:-1],"+-",label ="Article")
ax.set_xlabel("Mode index")
ax.set_ylabel("Mode frequency (GHz)")
ax.grid()
ax.legend()
#plt.show()
fig.savefig("article_fit_rep_cable_V2.png")

# %%
fitted_params, fitted_f_s = analysis.eigenmode_fit(article_theoretical_data, y_eqs[0],[L_j0_val,C_j0_val,C_g_val,C_0_val])
[L_j0_fit,C_j0_fit,C_g_fit,C_0_fit] = fitted_params
print(f"L_j0_fit : {L_j0_fit} || L_j0_val : {L_j0_val}")
print(f"C_j0_fit : {C_j0_fit} || C_j0_val : {C_j0_val}")
print(f"C_g_fit : {C_g_fit} || C_g_val : {C_g_val}")
print(f"C_0_fit : {C_0_fit} || C_0_val : {C_0_val}")
# Out:
# Fit failed
# L_j0_fit : 151.99999999669978 || L_j0_val : 152.0
# C_j0_fit : 5.018505835899004e-07 || C_j0_val : 5.000000000000001e-07
# C_g_fit : 7.520518049324026e-08 || C_g_val : 8e-08
# C_0_fit : 9.913624195586365e-07 || C_0_val : 1e-06

# %%
plt.plot([el[0] for el in fitted_f_s][:9],"o-",label=f"Zeros of Y_eq (C_0 = {round(C_0_fit*1e6,2)} fF)")
plt.plot(article_theoretical_data,"+-",label ="Article_data")
plt.xlabel("Mode index")
plt.ylabel("Mode frequency (GHz)")
plt.legend()
plt.show()
